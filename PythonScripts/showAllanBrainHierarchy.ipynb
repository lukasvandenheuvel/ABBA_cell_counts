# %%
import pandas as pd
import json
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout

from plot_helpers import plot_plotly_graph

# %%
def load_allen_brain_hierarchy(path_to_allen_json):
    # Load json file
    with open(path_to_allen_json,) as file:
        allen_data = json.load(file)

    # Unpack json
    count = 0
    while True:
        record = ['msg'] + ['children']*count
        df = pd.json_normalize(allen_data,record_path=record)
        if count==0:
            allen_df = df.copy()
        else:
            allen_df = pd.concat([allen_df, df])
        count += 1

        if df.empty:
            break
    
    allen_df = allen_df.rename(columns={'name':'region_name'})
    return allen_df

# %%
# Show the first three regions
path_to_allen_json = '../AllenMouseBrainOntology.json'
allen_df = load_allen_brain_hierarchy(path_to_allen_json)
allen_df.head(3)
# Out:
#      id atlas_id  ontology_id       acronym                    region_name  \
# 0   997     -1.0            1          root                           root
# 0     8      0.0            1          grey  Basic cell groups and regions
# 1  1009    691.0            1  fiber tracts                   fiber tracts
#
#   color_hex_triplet  graph_order  st_level  hemisphere_id parent_structure_id  \
# 0            FFFFFF            0         0              3                None
# 0            BFDAE3            1         1              3                 997
# 1            CCCCCC         1101         1              3                 997
#
#                                             children
# 0  [{'id': 8, 'atlas_id': 0, 'ontology_id': 1, 'a...
# 0  [{'id': 567, 'atlas_id': 70, 'ontology_id': 1,...
# 1  [{'id': 967, 'atlas_id': 686, 'ontology_id': 1...

# %%
# Load graph as nx object
G = nx.from_pandas_edgelist(brain_df, 'id', 'parent_structure_id', 
                            create_using = nx.DiGraph())

# Remove the node called 'None'
G.remove_node(None)

# Set the index of the brain DF as 'id'
brain_df = brain_df.set_index('id')

# %%
# Add attributes to the regions
attribute_columns = ['acronym','region_name','color_hex_triplet']
for col_name in attribute_columns:
    nx.set_node_attributes(G, brain_df[col_name].to_dict(), col_name)

# %%
# Calculate positions of the nodes (this may take some time)
pos = graphviz_layout(G, prog='dot')

# %%
# Plot brain region hierarchy
fig = plot_plotly_graph(G,pos)
fig.show()
# Out:
# <div>                            <div id="2154e77c-beb7-4e8e-b19d-a7cf136a0a5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2154e77c-beb7-4e8e-b19d-a7cf136a0a5e")) {                    Plotly.newPlot(                        "2154e77c-beb7-4e8e-b19d-a7cf136a0a5e",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[38061.0,50627.0,null,47877.0,50627.0,null,50627.0,50627.0,null,50885.0,50627.0,null,50984.0,50627.0,null,25048.0,38061.0,null,35695.0,38061.0,null,41915.0,38061.0,null,45203.0,47877.0,null,46579.0,47877.0,null,47780.0,47877.0,null,47877.0,47877.0,null,49183.0,47877.0,null,49687.0,47877.0,null,50447.0,50627.0,null,50519.0,50627.0,null,50591.0,50627.0,null,50663.0,50627.0,null,50735.0,50627.0,null,50807.0,50627.0,null,50885.0,50885.0,null,51455.0,50885.0,null,51529.0,50885.0,null,23840.0,25048.0,null,25048.0,25048.0,null,31597.0,35695.0,null,34644.0,35695.0,null,36264.0,35695.0,null,41915.0,41915.0,null,43450.0,41915.0,null,44265.0,45203.0,null,44337.0,45203.0,null,44409.0,45203.0,null,44589.0,45203.0,null,44877.0,45203.0,null,44949.0,45203.0,null,